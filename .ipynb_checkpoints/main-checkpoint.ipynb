# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Get Data from DB

# %%
import pymongo


connection_string = 'mongodb+srv://hafidz_erdityo:{MONGO_PASS}@cluster0.uorwk7c.mongodb.net/?retryWrites=true&w=majority'
client = pymongo.MongoClient(connection_string)
print(client)

# %%
data = client['social_media']['twitter_old'].find({'tanggal':'2022-06-24'})

# %%
baru = []
for i in tqdm(data):
    baru.append(i)
# Out:
# 9503it [00:44, 212.52it/s]

# %%
import pandas as pd

# %%
df = pd.DataFrame(baru)
df
# Out:
#                            _id  \
# 0     62b5704423b8dd081ede3d23
# 1     62b5703923b8dd081ede3c1f
# 2     62b57032670ee007a7c6500b
# 3     62b5702c23b8dd081ede3ae2
# 4     62b5702823b8dd081ede3a8f
# ...                        ...
# 9498  62b5620f670ee007a7c51fa8
# 9499  62b57d32d5887f0850057fac
# 9500  62b57cc5670ee007a7c72e80
# 9501  62b56dfc670ee007a7c61fa9
# 9502  62b5db99d5887f085013878d
#
#                                                    user  \
# 0     {'id': '1408817989848166402', 'name': 'Mili li...
# 1     {'id': '1148133505110441984', 'name': 'Detax I...
# 2     {'id': '1222410650925719552', 'name': 'Humas P...
# 3     {'id': '1506478694386180097', 'name': 'Faris i...
# 4     {'id': '1408817989848166402', 'name': 'Mili li...
# ...                                                 ...
# 9498  {'id': '2385543769', 'name': 'bangsaonline', '...
# 9499  {'id': '65991060', 'name': 'Hidayatullah.com',...
# 9500  {'id': '65991060', 'name': 'Hidayatullah.com',...
# ...

# %%
df['label'] = df['analysis'].apply(lambda x: x['sentiment']['sentiment'])

# %%
df = df[['content','label']]

# %%
df.rename({'content':'fitur'}, axis=1, inplace=True)
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_10308\1279759266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'content':'fitur'}, axis=1, inplace=True)

# %%
df
# Out:
#                                                   fitur label
# 0     @ebn_sumbar @prabowo @Kemhan_RI Sepakat nih, V...   net
# 1     [Hoax] Anies Baswedan Pendiri dan Deklarator P...   net
# 2     Polsek Gunung Kerinci  Polres Kerinci Cek Harg...   neg
# 3     Maju terus Prabowo Subianto, jadi Pilihan Indo...   pos
# 4     @ebnlampung @prabowo @Kemhan_RI info ya, Kemer...   pos
# ...                                                 ...   ...
# 9498  Pemilu 2024, Demokrat Kota Probolinggo Targetk...   pos
# 9499  Suporter sepak bola identik dengan tawuran, ta...   net
# 9500  Pidato Mantan Presiden RI Megawati Soekarnoput...   neg
# 9501  Demo Tolak Konversi Teh ke Sawit: Copot Dirut ...   net
# 9502  Kemenangan meyakinkan kembali dicatat PSIS di ...   pos
#
# [9503 rows x 2 columns]

# %% [markdown]
# ### Function Setup

# %%
from sklearn.pipeline import Pipeline
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
import re
import nltk


def f_casefold(arg_text: str) -> str:
    """
    @desc: this function is lowering raw text

    @params:
        - arg_text: raw string that need to be casefolded (str)

    @returns:
        - arg_text: casfolded string (str)
    """
    arg_text = arg_text.casefold().strip()
    return arg_text


def f_text_cleansing(arg_str: str) -> str:
    """
    @desc: this function is cleaning raw text that is already tokenized

    @params:
        - arg_text: raw string that need to be cleansed (str)

    @returns:
        - cleaned_text: cleaned string (str)
    """
    if isinstance(arg_str, str):
        # cleanse hashtag and mention
        # cleanse mention hashtag
        arg_str = re.sub(r'(?:#|@)[A-Za-z0-9_]+', '', arg_str)
        arg_str = re.sub(r'(?:https?|www)\S+', '', arg_str)  # cleanse url
        cleaned_text = ''
        for each_letter in arg_str:
            if each_letter.isalpha() or each_letter == ' ':
                cleaned_text += each_letter
        return cleaned_text
    else:
        raise Exception("Only string are Allowed")


def f_tokenizing(arg_text: str) -> list:
    """
    @desc: this function is splitting string into list by it's own space

    @params:
        - arg_text: raw string that need to be splitted (str)

    @returns:
        - out_list: splitted text (list)
    """
    # Transform jadi list, dan split tiap kata berdasarkan space
    if isinstance(arg_text, str):
        out_list = arg_text.split()
        return out_list
    else:
        raise Exception("Only string are Allowed")


words_filter = stopwords.words('indonesian', 'english')
# Pake stopwords dari library nltk buat hilangin kata hubung such as "sangat", " yang", "ketika" dll


def f_stopword(arg_list: list) -> list:
    """
    @desc: this function is filtering string inside a list that not in stopword library

    @params:
        - arg_list: list of string (list)

    @returns:
        - stopped_list: filtered list of string (list)
    """
    if isinstance(arg_list, list):
        stopped_list = list(filter(lambda word: (
            word not in words_filter) and (len(word) > 1), arg_list))
        return stopped_list
    else:
        raise Exception("Only List are Allowed")


# Stemming pake library sastrawi buat menghilangkan imbuhan, such as "mendegar" jadi "dengar"
# "berlari" jadi "lari"
factory = StemmerFactory()
stemmer = factory.create_stemmer()


def f_stemming(arg_list: list) -> str:
    """
    @desc: this function is cleaning string inside a list using sastrawi

    @params:
        - arg_list: list of string (list)

    @returns:
        - d_clean: sastrawi-ed string (string)
    """
    cleaned = []
    for i in arg_list:
        cleaned.append(stemmer.stem(i))
    d_clean = " ".join(cleaned)
    return d_clean

# %% [markdown]
# ### Applying function

# %%
df['fitur'] = df['fitur'].apply(f_casefold)
df
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_10308\2457424504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fitur'] = df['fitur'].apply(f_casefold)
#                                                   fitur label
# 0     @ebn_sumbar @prabowo @kemhan_ri sepakat nih, v...   net
# 1     [hoax] anies baswedan pendiri dan deklarator p...   net
# 2     polsek gunung kerinci  polres kerinci cek harg...   neg
# 3     maju terus prabowo subianto, jadi pilihan indo...   pos
# 4     @ebnlampung @prabowo @kemhan_ri info ya, kemer...   pos
# ...                                                 ...   ...
# 9498  pemilu 2024, demokrat kota probolinggo targetk...   pos
# 9499  suporter sepak bola identik dengan tawuran, ta...   net
# ...

# %%
df['fitur'] = df['fitur'].apply(f_text_cleansing)
df
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_10308\1074768142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fitur'] = df['fitur'].apply(f_text_cleansing)
#                                                   fitur label
# 0        sepakat nih visi pak prabowo selesaikan ber...   net
# 1     hoax anies baswedan pendiri dan deklarator par...   net
# 2     polsek gunung kerinci  polres kerinci cek harg...   neg
# 3     maju terus prabowo subianto jadi pilihan indon...   pos
# 4        info ya kemerdekaan dan rasa aman menjadika...   pos
# ...                                                 ...   ...
# 9498  pemilu  demokrat kota probolinggo targetkan  k...   pos
# 9499  suporter sepak bola identik dengan tawuran tap...   net
# ...

# %%
df['fitur'] = df['fitur'].apply(f_tokenizing)
df
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_10308\2547359362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fitur'] = df['fitur'].apply(f_tokenizing)
#                                                   fitur label
# 0     [sepakat, nih, visi, pak, prabowo, selesaikan,...   net
# 1     [hoax, anies, baswedan, pendiri, dan, deklarat...   net
# 2     [polsek, gunung, kerinci, polres, kerinci, cek...   neg
# 3     [maju, terus, prabowo, subianto, jadi, pilihan...   pos
# 4     [info, ya, kemerdekaan, dan, rasa, aman, menja...   pos
# ...                                                 ...   ...
# 9498  [pemilu, demokrat, kota, probolinggo, targetka...   pos
# 9499  [suporter, sepak, bola, identik, dengan, tawur...   net
# ...

# %%
df['fitur'] = df['fitur'].apply(f_stopword)
df
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_10308\376705923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fitur'] = df['fitur'].apply(f_stopword)
#                                                   fitur label
# 0     [sepakat, nih, visi, prabowo, selesaikan, perm...   net
# 1     [hoax, anies, baswedan, pendiri, deklarator, p...   net
# 2     [polsek, gunung, kerinci, polres, kerinci, cek...   neg
# 3     [maju, prabowo, subianto, pilihan, indonesia, ...   pos
# 4     [info, ya, kemerdekaan, aman, menjadikan, indo...   pos
# ...                                                 ...   ...
# 9498  [pemilu, demokrat, kota, probolinggo, targetka...   pos
# 9499  [suporter, sepak, bola, identik, tawuran, ciom...   net
# ...

# %%
def additional_stopword(arg_list):
    add_stop = "anies baswedan prabowo subianto ridwan kamil erick thohir puan maharani agus harimurti yudhoyono airlangga hartanto ganjar pranowo jokowi megawati khofifah indar parawansa muhaimin iskandar sandiaga uno"
    arg_list = list(filter(lambda x:x not in add_stop, arg_list))
    return arg_list

# %%
df['fitur'] = df['fitur'].apply(additional_stopword)
df
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_10308\4043095442.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fitur'] = df['fitur'].apply(additional_stopword)
#                                                   fitur label
# 0     [sepakat, nih, visi, selesaikan, permasalahan,...   net
# 1      [hoax, pendiri, deklarator, partai, nasdem, via]   net
# 2     [polsek, gunung, kerinci, polres, kerinci, cek...   neg
# 3     [maju, pilihan, indonesia, kerja, rakyat, kerj...   pos
# 4     [info, ya, kemerdekaan, aman, menjadikan, indo...   pos
# ...                                                 ...   ...
# 9498  [pemilu, demokrat, kota, probolinggo, targetka...   pos
# 9499  [suporter, sepak, bola, identik, tawuran, ciom...   net
# ...

# %%
# # for i in df['label'].unique():
# df_subset = df[df['label'] == 'net'].sample(40000)
# df = df.drop(df_subset.index)

# %%
df.groupby(['label']).count()['fitur']
# Out:
# label
# neg    2157
# net    3546
# pos    3800
# Name: fitur, dtype: int64

# %%
df['fitur'] = df['fitur'].apply(lambda x: " ".join(x))
df
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_10308\1472070224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fitur'] = df['fitur'].apply(lambda x: " ".join(x))
#                                                   fitur label
# 0     sepakat nih visi selesaikan permasalahan keama...   net
# 1             hoax pendiri deklarator partai nasdem via   net
# 2     polsek gunung kerinci polres kerinci cek harga...   neg
# 3     maju pilihan indonesia kerja rakyat kerja foku...   pos
# 4     info ya kemerdekaan aman menjadikan indonesia ...   pos
# ...                                                 ...   ...
# 9498  pemilu demokrat kota probolinggo targetkan kur...   pos
# 9499  suporter sepak bola identik tawuran ciomas bog...   net
# ...

# %%
# df['fitur'] = df['fitur'].apply(stemming)
# df

# %%
import json
with open('data_cleaned2.json', 'w') as f:
    json.dump(df.to_dict(orient='records'),f)

# %%
data_clean = df.astype({'fitur': 'string'})
data_clean = data_clean.astype({'label': 'category'})
data_clean.dtypes
# Out:
# fitur      string
# label    category
# dtype: object

# %% [markdown]
# ## Model

# %% [markdown]
# #### SVM

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

tfid = TfidfVectorizer()
model_select = svm.LinearSVC(multi_class='ovr')

# %%
model= Pipeline([('vectorizer',tfid)
                 ,('classifier',model_select)])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

X_train, X_test, y_train, y_test = train_test_split(data_clean['fitur'], data_clean['label'],stratify=data_clean['label'], test_size = 0.3)

fitted = model.fit(X_train, y_train)

y_pred = fitted.predict(X_test)
conf_mat = confusion_matrix(y_test,y_pred)

print(f'Accuracy: {accuracy_score(y_test,y_pred) * 100}%')
print(f'Confusion Matrix:\n {conf_mat}\n')
print(classification_report(y_test,y_pred,zero_division=0))
# Out:
# Accuracy: 75.69273938968783%
# Confusion Matrix:
#  [[413 177  57]
#  [134 768 162]
#  [ 45 118 977]]
#
#               precision    recall  f1-score   support
#
#          neg       0.70      0.64      0.67       647
#          net       0.72      0.72      0.72      1064
#          pos       0.82      0.86      0.84      1140
#
#     accuracy                           0.76      2851
#    macro avg       0.75      0.74      0.74      2851
# weighted avg       0.75      0.76      0.76      2851

# %% [markdown]
# ### Save Model

# %%
import pickle

filename = 'finalized_model.sav'
pickle.dump(fitted, open(filename, 'wb'))

# %%
### Percobaan duniawi
import sentiment_model


kata = [
    'Kayak txtdariberseragam jrit kalau gw baca sekarang. Dulu kayaknya gw seneng banget pas dikirimin itu. :"',
    'Mendengarkan dengan khusyuk segala omong kosongmu',
    'Kalian pernah ngga sih sebel sama diri sendiri, kayak "ah anjir kenapa sih gua begitu"',
    'Inisial nama seseorang yang kelakuannya kayak tai',
    'Masih seger dan siap menaklukan dunia',
    'Terima kasih timnas u-16, akhirnya indonesia merasakan lagi indahnya menjadi juara!',
    'Kadang ada aja orang yang sok lebih tau sama hidup kita daripada kitanya sendiri'
    ]

print('Twitter Account: @andihiyat')
print('='*120)

for i in kata:
    print(i)
    get_sen = sentiment_model.get_sentiment(i)
    if get_sen =='pos':
        print('Sentiment: Positif')
    elif get_sen =='neg':
        print('Sentiment: Negatif')
    else:
        print('Sentiment: Netral')
    print('-' * 50)
# Out:
# Twitter Account: @andihiyat
# ...
# Kayak txtdariberseragam jrit kalau gw baca sekarang. Dulu kayaknya gw seneng banget pas dikirimin itu. :"
# Sentiment: Negatif
# --------------------------------------------------
# Mendengarkan dengan khusyuk segala omong kosongmu
# Sentiment: Negatif
# --------------------------------------------------
# Kalian pernah ngga sih sebel sama diri sendiri, kayak "ah anjir kenapa sih gua begitu"
# Sentiment: Negatif
# --------------------------------------------------
# Inisial nama seseorang yang kelakuannya kayak tai
# Sentiment: Negatif
# --------------------------------------------------
# Masih seger dan siap menaklukan dunia
# Sentiment: Netral
# --------------------------------------------------
# Terima kasih timnas u-16, akhirnya indonesia merasakan lagi indahnya menjadi juara!
# Sentiment: Positif
# --------------------------------------------------
# Kadang ada aja orang yang sok lebih tau sama hidup kita daripada kitanya sendiri
# ...

# %%
### Percobaan duniawi
import sentiment_model


kata = [
    '''Pagi-siang mendampingi Presiden 
@jokowi
 & Ibu Iriana di ragam kegiatan sosial di Kota Bandung. Sehat selalu Pak Presiden dan Ibu.

Sore gantian, mendampingi Arka yang ingin jalan-jalan ke pinggiran kota.

Karena hidup harus selalu seimbang antara tugas negara dan tugas keluarga.''',
    '''#CyclingDeJabar, kompetisi sepeda melintasi Jabar Selatan ini saya buka di Geopark Ciletuh. Start di Sukabumi berakhir di Pangandaran.

Lautan, pantai, gunung, sawah diselingi beragam air terjun akan terlewati oleh rute indah ini. Program ini bekerja sama dengan 
@hariankompas
.''',
    '''Minggu produktif, mendampingi Presiden RI 
@jokowi
 dalam meninjau Pasar Cicaheum, Bandung. Kunker Presiden kali ini dalam rangka penyerahan bansos & bantuan modal kerja kepada penerima manfaat untuk tambahan modal usaha. Alhamdulillah. #JabarJuara #IndonesiaJuara -admin-'''
]
print('Twitter Account: @ridwankamil')
print('='*120)
for i in kata:
    print(i)
    get_sen = sentiment_model.get_sentiment(i)
    if get_sen == 'pos':
        print('Sentiment: Positif')
    elif get_sen == 'neg':
        print('Sentiment: Negatif')
    else:
        print('Sentiment: Netral')
    print('-' * 100)
# Out:
# Twitter Account: @ridwankamil
# ...
# Pagi-siang mendampingi Presiden
# @jokowi
#  & Ibu Iriana di ragam kegiatan sosial di Kota Bandung. Sehat selalu Pak Presiden dan Ibu.
#
# Sore gantian, mendampingi Arka yang ingin jalan-jalan ke pinggiran kota.
#
# Karena hidup harus selalu seimbang antara tugas negara dan tugas keluarga.
# Sentiment: Positif
# ----------------------------------------------------------------------------------------------------
# #CyclingDeJabar, kompetisi sepeda melintasi Jabar Selatan ini saya buka di Geopark Ciletuh. Start di Sukabumi berakhir di Pangandaran.
#
# Lautan, pantai, gunung, sawah diselingi beragam air terjun akan terlewati oleh rute indah ini. Program ini bekerja sama dengan
# @hariankompas
# .
# Sentiment: Positif
# ----------------------------------------------------------------------------------------------------
# Minggu produktif, mendampingi Presiden RI
# @jokowi
# ...

# %% [markdown]
# # Analytics

# %%
import re
import collections

words_filter = stopwords.words('indonesian', 'english')
# Pake stopwords dari library nltk buat hilangin kata hubung such as "sangat", " yang", "ketika" dll


def f_stopword(arg_list: list) -> list:
    """
    @desc: this function is filtering string inside a list that not in stopword library

    @params:
        - arg_list: list of string (list)

    @returns:
        - stopped_list: filtered list of string (list)
    """
    words_filter.extend([
        '',':)','&amp','ya','yg','mimin','kirim','halo','||'
    ])
    if isinstance(arg_list, list):
        stopped_list = list(filter(lambda word: word not in words_filter, arg_list))
        return stopped_list
    else:
        raise Exception("Only List are Allowed")
        
def ekstrak_mention(x):
    get_men = re.findall(r'(?:@)\S+',x)
    return get_men

def ekstrak_topic(x):
    big_str = ''
    for i in x:
            big_str += i + ' '
    big_str = re.sub(r'(?:@|#)\S+','', big_str)
    splitted = big_str.lower().split()
    splitted = f_stopword(splitted)
    return collections.Counter(splitted).most_common()

# %%
import json
instansi = ['jne','jnt','pos','sicepat']

kompetitor_data = {}


for each_in in instansi:
    with open('{}.json'.format(each_in)) as f:
        kompetitor_data[each_in] = json.load(f)

# %%
import pandas as pd
df_jne = pd.DataFrame(kompetitor_data['jne'])

# %%
import datetime
df_jne['tanggal'] = df_jne['datetime_ms'].apply(lambda x:datetime.datetime.fromtimestamp(x/1000.0).strftime("%d/%m/%Y").replace('/','-'))

# %%
df_jne.columns
# Out:
# Index(['_index', '_type', '_id', 'id', 'meta', 'user', 'content', 'analysis',
#        'keywords', 'hashtags', 'quote_count', 'reply_count', 'retweet_count',
#        'favorite_count', 'source', 'in_reply_to_screen_name',
#        'in_reply_to_user_id_str', 'in_reply_to_status_id_str', 'geolocation',
#        'tweet_location', 'location_id', 'location', 'priority', 'datetime_ms',
#        'tanggal'],
#       dtype='object')

# %%
df_jne = df_jne[['id','tanggal','content','hashtags']]

# %%
df_jne['mention'] = df_jne['content'].apply(ekstrak_mention)

# %% [markdown]
# ### Top Hashtag

# %%
list_ht = []
for i in df_jne['hashtags'].to_list():
    for j in i:
        list_ht.append(j)

# %%
import collections

top5_ht = collections.Counter(list_ht).most_common()

top5_ht
# Out:
# [('#JNESemarakNgetweet', 164),
#  ('#JNEsemarak17an', 127),
#  ('#JNEsemarakNgetweet', 105),
#  ('#jnesemarak17an', 93),
#  ('#JNE', 81),
#  ('#JNESemarak17an', 71),
#  ('#JNEBLITAR', 67),
#  ('#ConnectingHappiness', 57),
#  ('#JNEMajuIndonesia', 54),
#  ('#JNE31Tahun', 53),
#  ('#jne', 36),
#  ('#terimakasih', 28),
#  ('#connectinghappiness', 24),
#  ('#jne31tahun', 22),
#  ('#jnemajuindonesia', 22),
#  ('#Indonesia', 20),
#  ('#TemanJNE', 18),
#  ('#DukungJNE', 18),
#  ('#FFI', 18),
#  ('#cuscikru', 16),
#  ('#InfoWebinar', 11),
#  ('#JneSemarak17an', 10),
#  ('#FreeWebinar', 10),
#  ('#InfoEvent', 9),
#  ('#JNENgajakOnline2022', 9),
#  ('#temanjne', 8),
#  ('#Vaksin', 8),
#  ('#padang', 8),
#  ('#ffi', 8),
#  ('#jneblitar', 7),
#  ('#sumaterabarat', 7),
#  ('#CosmoJNE', 7),
#  ('#jakarta', 7),
#  ('#FFI19062022', 7),
#  ('#asiyahsofyan', 6),
#  ('#jneid', 6),
#  ('#jnepadang', 6),
#  ('#YellowSub', 6),
#  ('#JNEDEPOK', 6),
#  ('#ffi25062022', 6),
#  ('#indonesia', 6),
# ...

# %%
import matplotlib.pyplot as plt

x = [i[0] for i in top5_ht[:6]]
y = [i[1] for i in top5_ht[:6]]
plt.bar(x,y)
plt.xticks(rotation =50)
plt.show()

# %% [markdown]
# ### Top Mention

# %%
list_ht = []
for i in df_jne['mention'].to_list():
    for j in i:
        list_ht.append(j)

# %%
top5_ht = collections.Counter(list_ht).most_common()

top5_ht
# Out:
# [('@JNECare', 1129),
#  ('@JNE_ID', 760),
#  ('@JNECare.', 54),
#  ('@Ursia_I', 40),
#  ('@ShopeeID', 34),
#  ('@hykagyu_', 33),
#  ('@tokopedia', 27),
#  ('@TokopediaCare', 26),
#  ('@ShopeeCare', 25),
#  ('@slaypii', 19),
#  ('@sbtcon', 18),
#  ('@DivHumas_Polri', 18),
#  ('@ayy658', 17),
#  ('@ganjarpranowo', 16),
#  ('@anteraja_id', 16),
#  ('@AREAJULID', 14),
#  ('@jntexpressid', 14),
#  ('@catchmeupid', 14),
#  ('@KemensosRI', 13),
#  ('@jokowi', 13),
#  ('@sicepat_ekspres', 12),
#  ('@YLKI_ID', 12),
#  ('@alextham878', 12),
#  ('@SantorinisSun', 11),
#  ('@Slavd3', 11),
#  ('@ahadahad', 10),
#  ('@DPR_RI', 9),
#  ('@jne_id', 9),
#  ('@belacinderela1', 9),
#  ('@Orochim77279375', 9),
#  ('@pengarang_sajak', 9),
#  ('@nahdlatululama', 9),
#  ('@MuhammadAArrofi', 9),
#  ('@cikaall_rr', 9),
#  ('@ex_Lolina', 8),
#  ('@april_hamsa', 8),
#  ('@KinanSport2', 8),
#  ('@andiwibowo2024', 8),
#  ('@adhit_wr', 8),
#  ('@FaizalPKaliman', 8),
#  ('@HendyPiliang', 8),
# ...

# %%
x = [i[0] for i in top5_ht[:10]]
y = [i[1] for i in top5_ht[:10]]
plt.bar(x,y)
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ### Top Topic

# %%
list_topik = df_jne['content'].to_list()

# %%
list_topik
# Out:
# ['@rizal26 Hai kak Rizal. Mohon maaf maksudnya pengaktifan nomor resi seperti apa kak? Jika paket sdh diserahkan ke JNE dan sdh masuk ke sistem maka akan terbit nomor resinya ya. Thx ^Rio',
#  'Jumper Macbeth Logo  || Bahan Cotton Fleece || Size Fit L || Cek di https://t.co/If5ftQ1rgG :) https://t.co/rhP0slCrOu',
#  '@JNECare Semua paket no hp dihide sebagian. JNE malah share disini. Apa namanya. Hapus min. Belajar lg etika bermedsos',
#  "tolong dong ini, paketnya terkirim tapi saya ataupun anggota keluarga lain terutama 'mbah' atau nenek/kakek saya tidak ada yang menerima paket apapun @JNECare @JNE_ID https://t.co/dK3v7v87y0",
#  '@AREAJULID Tai alesan kemanusiaan , sue2 hukum Indonesia Ki lawak. Ws Ddi ts isih wae di kei alesan kemanusiaan , utek mu do utek apa to. Emosi njir . Kui jne nek di santet ngno pie to si fs ambe pc kok gedek nyawang e',
#  'Jaket Bolak Balik Polos || Bahan Parasut&amp;Fleece || Size Fit L || Cek di https://t.co/If5ftQjAuO :) https://t.co/Qo4rn7FpAx',
# ...

# %%
extracted_topik = ekstrak_topic(list_topik)
extracted_topik
# Out:
# [('jne', 2226),
#  ('cek', 729),
#  ('paket', 669),
#  ('mohon', 568),
#  ('bahan', 504),
#  ('ga', 492),
#  ('indonesia', 443),
#  ('terkait', 435),
#  ('via', 433),
#  ('size', 419),
#  ('fit', 414),
#  ('l', 414),
#  ('cotton', 402),
#  ('fleece', 402),
#  ('dm', 387),
#  ('maaf', 362),
#  ('jaket', 328),
#  ('barang', 314),
#  ('kak', 304),
#  ('aja', 302),
#  ('admin', 302),
#  ('resi', 289),
#  ('pengiriman', 286),
#  ('kak.', 281),
#  ('de', 273),
#  ('no', 263),
#  ('&amp;', 232),
#  ('udah', 224),
#  ('jakarta', 222),
#  ('kakak', 221),
#  ('nya', 221),
#  ('pake', 219),
#  ('thanks', 211),
#  ('https://t.co/if5ftqjauo', 196),
#  ('sejahtera', 193),
#  ('harga', 192),
#  ('selamat', 190),
#  ('kak,', 182),
#  ('la', 182),
#  ('kemerdekaan', 182),
#  ('-', 178),
#  ('kota', 174),
#  ('gak', 173),
#  ('sampe', 172),
#  ('|', 170),
#  ('kalo', 170),
#  ('terima', 170),
#  ('semoga', 166),
#  ('tgl', 166),
#  ('kurir', 158),
#  ('pembayaran', 157),
# ...

# %% [markdown]
# ### Sentiment Pie

# %%
import sentiment_model
from tqdm import tqdm


df_jne['sen'] = df_jne['content'].apply(lambda x: sentiment_model.get_sentiment(x))

# %%
jne_sen_agg = df_jne.groupby(['sen']).count()['id']

# %%
jne_sen_agg.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='id'>

# %%
df_jne_pos = df_jne[df_jne['sen'] == 'neg']

# %%
for i in df_jne_pos.iterrows():
    print(i[1]['content'])
    print('SENTIMENT: [', i[1]['sen'],']')
    print('='*100)
# Out:
# @AREAJULID Tai alesan kemanusiaan , sue2 hukum Indonesia Ki lawak. Ws Ddi ts isih wae di kei alesan kemanusiaan , utek mu do utek apa to. Emosi njir . Kui jne nek di santet ngno pie to si fs ambe pc kok gedek nyawang e
# SENTIMENT: [ neg ]
# ...
# @77thfloor_ Barang berharga kah? Aku pernah punya masalah sama JNE dan bisa habisin seharian buat ngurus beginian.
# SENTIMENT: [ neg ]
# ...
# Selasa (30/8), JNE yang diwakili oleh Bapak Chandra Fireta selaku Direktur JNE dan Ibu Riri Lenggogini selaku Head Of Human Capital Development Division JNE melepas 64 jamaah umroh kloter ke 2 yang merupakan karyawan JNE untuk beribadah ke tanah suci Mekkah selama 11 hari. https://t.co/mhvUDEjdxK
# SENTIMENT: [ neg ]
# ...
# @JNECare Mana tdk ada info paket saya dimana?
# Hanya disuruh nunggu. Yah kalo nunggu mah gak sampe seminggu juga kali. Semua org punya batas sabar bukan?  Dan saya yg kena omelan cust saya. Makasihh yaa min.. pengalaman buruknya akan sangat ingat. Thx
# SENTIMENT: [ neg ]
# ...

# %% [markdown]
# ## Pos Indonesia

# %%
df_pos = pd.DataFrame(kompetitor_data['pos'])

# %%
df_pos
# Out:
#                        _index _type                  _id                   id  \
# 0     db_twitter_tweet-000016  _doc  1565258105998704640  1565258105998704640
# 1     db_twitter_tweet-000016  _doc  1565253452540051456  1565253452540051456
# 2     db_twitter_tweet-000016  _doc  1565253411586863104  1565253411586863104
# 3     db_twitter_tweet-000016  _doc  1565253324768948226  1565253324768948226
# 4     db_twitter_tweet-000016  _doc  1565252209704517632  1565252209704517632
# ...                       ...   ...                  ...                  ...
# 1197  db_twitter_tweet-000014  _doc  1532907754117304320  1532907754117304320
# 1198  db_twitter_tweet-000014  _doc  1532906798927478784  1532906798927478784
# 1199  db_twitter_tweet-000014  _doc  1532807489799847936  1532807489799847936
# 1200  db_twitter_tweet-000014  _doc  1532789358553878528  1532789358553878528
# 1201  db_twitter_tweet-000014  _doc  1532769999504322560  1532769999504322560
#
# ...

# %%
df_pos['tanggal'] = df_pos['datetime_ms'].apply(lambda x:datetime.datetime.fromtimestamp(x/1000.0).strftime("%d/%m/%Y").replace('/','-'))

# %%
df_pos = df_pos[['id','tanggal','content','hashtags']]
df_pos
# Out:
#                        id     tanggal  \
# 0     1565258105998704640  01-09-2022
# 1     1565253452540051456  01-09-2022
# 2     1565253411586863104  01-09-2022
# 3     1565253324768948226  01-09-2022
# 4     1565252209704517632  01-09-2022
# ...                   ...         ...
# 1197  1532907754117304320  04-06-2022
# 1198  1532906798927478784  04-06-2022
# 1199  1532807489799847936  04-06-2022
# 1200  1532789358553878528  04-06-2022
# 1201  1532769999504322560  04-06-2022
#
#                                                 content hashtags
# 0     @ArtKaolinite91 @PosIndonesia @BNI Hallo kak.\...       []
# 1     @ArtKaolinite91 @PosIndonesia @BNI Hai, pak/bu...       []
# 2     @ArtKaolinite91 @PosIndonesia @BNI 'Hallo kak....       []
# 3     @ArtKaolinite91 @PosIndonesia @BNI 'Hallo kak....       []
# 4     @ArtKaolinite91 @PosIndonesia @BNI Hay kak,\nm...       []
# ...                                                 ...      ...
# ...

# %%
df_pos['mention'] = df_pos['content'].apply(ekstrak_mention)

# %%
df_pos['sen'] = df_pos['content'].apply(lambda x: sentiment_model.get_sentiment(x))
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_14796\3290401466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['sen'] = df_pos['content'].apply(lambda x: sentiment_model.get_sentiment(x))

# %%
pos_sen_agg = df_pos.groupby(['sen']).count()['id']

# %%
pos_sen_agg.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='id'>

# %%
df_pos_pos = df_pos[df_pos['sen'] == 'neg']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 df_pos_pos = df_pos[df_pos['sen'] == 'neg']
#
# NameError: name 'df_pos' is not defined

# %%
for i in df_pos_pos.iterrows():
    print(i[1]['content'])
    print('SENTIMENT: [', i[1]['sen'],']')
    print('='*100)
# Out:
# @ArtKaolinite91 @PosIndonesia @BNI Hi kak! Untuk Pusat Bantuan Silahkan informasikan kendala melalui Iink dibawah
# https://t.co/wHFy7Rq3Jm
#  Tks- Yoga
# SENTIMENT: [ pos ]
# ...
# @PosIndonesia @BNI mau top up pospay via BNI kok gagal terus? 😢
# SENTIMENT: [ pos ]
# ...
# Erick Thohir memastikan bahwa subsidi BBM (BLT) melalui PT Pos Indonesia akan tepat sasaran dan tepat waktu. #erickthohir #sobaterick https://t.co/H11boSZDvD
# SENTIMENT: [ pos ]
# ...
# (BLT) cair mulai Kamis, 1 September 2022 Pemerintah akan menyalurkan BLT BBM sebesar Rp 600 ribu ke masyarakat yang terdaftar sebagai Keluarga Penerima Manfaat (KPM) BLT akan disalurkan melalui Pos Indonesia
#
# #PenyesuaianRingankanBeban
# Selamatkan Ekonomi Indonesia https://t.co/EeRGfIcVSH
# SENTIMENT: [ pos ]
# ...
# Bantuan Langsung Tunai (BLT) cair mulai Kamis, 1 September 2022 Pemerintah akan menyalurkan BLT BBM sebesar Rp 600 ribu ke masyarakat yang terdaftar sebagai Keluarga Penerima Manfaat (KPM) BLT akan disalurkan melalui Pos Indonesia
# ...

# %% [markdown]
# ### Top topic

# %%
list_topik = df_pos['content'].to_list()

# %%
extracted_topic = ekstrak_topic(list_topik)

# %%
extracted_topic
# Out:
# [('pos', 936),
#  ('indonesia', 862),
#  ('pt', 186),
#  ('barang', 171),
#  ('shopee', 123),
#  ('&amp;', 121),
#  ('sahabat', 115),
#  ('mohon', 112),
#  ('tokopedia', 112),
#  ('negeri', 96),
#  ('-jasa', 96),
#  ('dm', 95),
#  ('maaf', 88),
#  ('kerja', 85),
#  ('terkait', 82),
#  ('kantor', 78),
#  ('paket', 74),
#  ('jasa', 74),
#  ('ga', 69),
#  ('udah', 68),
#  ('pake', 66),
#  ('ekspor', 64),
#  ('pelayanan', 61),
#  ('pengiriman', 60),
#  ('logistik', 60),
#  ('titip', 60),
#  ('blt', 58),
#  ('co', 56),
#  ('layanan', 54),
#  ('silakan', 53),
#  ('bumn', 53),
#  ('-', 53),
#  ('kiriman', 51),
#  ('bank', 50),
#  ('bayar', 50),
#  ('aja', 49),
#  ('kantorpos', 49),
#  ('makasih', 49),
#  ('2', 48),
#  ('|', 48),
#  ('/', 48),
#  ('bantu', 46),
#  ('via', 46),
#  ('jakarta', 45),
#  ('shopee,', 44),
#  ('terima', 43),
#  ('ya,', 43),
#  ('sahabat,', 42),
#  ('kalo', 42),
#  ('pangan', 42),
#  ('2022', 41),
#  ('gak', 41),
#  ('nya', 40),
#  ('ekonomi', 40),
#  ('pt.', 40),
# ...

# %%
topik_splitted = [i.lower() for i in topik_splitted]

# %%
topik_baru = f_stopword(topik_splitted)

# %%
topik_baru
# Out:
# ['@artkaolinite91',
#  '@posindonesia',
#  '@bni',
#  'hallo',
#  'kak.\nsilakan',
#  'lampir',
#  'untu',
#  'prihal',
#  'alami',
#  'link',
#  'bawa',
#  'bantu.\n',
#  '\nhttps://t.co/ed4f5b7sqc\n',
#  '𝐓𝐤𝐬-intan-',
#  '@artkaolinite91',
#  '@posindonesia',
#  '@bni',
#  'hai,',
#  'pak/buk',
#  'mohon',
#  'maaf',
#  'kendala',
#  'alami.',
#  'bantu',
#  'langsung',
#  'silahkan',
#  'hubungi',
#  'bank',
#  'bni.',
#  'live',
#  'chat',
#  'whattsapp',
#  'resmi',
#  'klik',
#  'link',
#  '👇👇',
#  '\n\nhttps://t.co/mfjo14c1ma',
#  "tks_nisa'\n\n.",
#  '@artkaolinite91',
#  '@posindonesia',
#  '@bni',
#  "'hallo",
#  'kak..\nsilakan',
#  'detail',
#  'kendala',
#  'nya',
#  'link',
#  'bawa',
#  'bantu.\nhttps://t.co/kxvfqhbsvd\n\n',
#  '𝐓𝐤𝐬~',
#  'bella.',
#  '@artkaolinite91',
#  '@posindonesia',
#  '@bni',
#  "'hallo",
#  'kak..\nsilakan',
#  'detail',
#  'kendala',
#  'nya',
#  'link',
#  'bawa',
#  'bantu.\nhttps://t.co/kxvfqhbsvd\n\n',
#  '𝐓𝐤𝐬~',
#  'bella',
# ...

# %%
top_topic = collections.Counter(topik_baru).most_common()

# %%
top_topic
# Out:
# [('pos', 930),
#  ('indonesia', 780),
#  ('@posindonesia', 296),
#  ('pt', 181),
#  ('barang', 169),
#  ('&amp;', 121),
#  ('sahabat', 115),
#  ('mohon', 108),
#  ('maaf', 85),
#  ('dm', 84),
#  ('kerja', 83),
#  ('terkait', 82),
#  ('shopee', 82),
#  ('kantor', 78),
#  ('paket', 72),
#  ('ga', 68),
#  ('udah', 66),
#  ('pake', 66),
#  ('pelayanan', 61),
#  ('pengiriman', 60),
#  ('logistik', 57),
#  ('blt', 56),
#  ('co', 56),
#  ('bumn', 53),
#  ('layanan', 52),
#  ('bank', 50),
#  ('-', 50),
#  ('kiriman', 50),
#  ('jasa', 50),
#  ('aja', 49),
#  ('kantorpos', 49),
#  ('makasih', 49),
#  ('|', 48),
#  ('/', 48),
#  ('2', 47),
#  ('negeri', 47),
#  ('via', 46),
#  ('bantu', 45),
#  ('jakarta', 44),
#  ('shopee,', 44),
#  ('ya,', 43),
#  ('silakan', 42),
#  ('sahabat,', 42),
#  ('terima', 42),
#  ('pangan', 42),
#  ('kalo', 41),
#  ('nya', 40),
#  ('ekonomi', 40),
#  ('gak', 40),
#  ('tokopedia', 40),
#  ('pt.', 39),
#  ('after', 39),
#  ('titip', 38),
#  ('kasih', 36),
# ...
